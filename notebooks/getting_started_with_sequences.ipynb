# %% [markdown]
# ## Referential Transparency
#
# **Selected Response:**  "Referential Transparency is a part of functional programming, in which an expression can be replaced with its resultant value without changing the behavior of the rest of the program."
#
# **Main point:** Substitution works!

# %% [markdown]
# ## Closure
#
# **Selected response:** Closure refers to a function that is bundled with outside values that it references. For example,

# %%
makedistanceconverter = lambda ratio: lambda feet: ratio*feet 
feettometers = makedistanceconverter(.3048) 
feettoinches = makedistanceconverter(12) 
a = feettometers(5) 
b = feettoinches(4) 
(a, b)
# Out:
# (1.524, 48)

# %% [markdown]
# The fact that we can use the same expression, makedistanceconverter, to produce two distinct functions, feettometers and feettoinches, illustrates the concept of closure.

# %% [markdown]
# **Main point:** Closures allow functions to "hold on" to values that would otherwise be lost.

# %% [markdown]
# ## DRY
#
# **Selected response:** A principle of software development, aimed at reducing repetition of information of all kinds. Code that has been generalized using abstractions can be used to solve not just one problem but many problems.
#
# ** Main point:** Generalizing functions with a similar "shape" reduces the amount of code and repetition.

# %%
# These two functions have the same "shape"
feettometers = lambda feet: 0.3048*feet 
feettoinches = lambda feet: 12*feet 
a = feettometers(5) 
b = feettoinches(4) 
(a, b)
# Out:
# (1.524, 48)

# %%
# Give the part of the code that differs a name.
# Use a lambda to abstract over this value
# Now this concept has one abstraction, not two
makedistanceconverter = lambda ratio: lambda feet: ratio*feet 
feettometers = makedistanceconverter(.3048) 
feettoinches = makedistanceconverter(12) 
a = feettometers(5) 
b = feettoinches(4) 
(a, b)
# Out:
# (1.524, 48)

# %% [markdown]
# ## Abstraction
# * **Selected Response 1:**  An abstraction is a simple representation of something that is complex. Abstractions are important in programming because they make it easy to work code that is usually hard to read and/or understand.
# * **Selected Response 2:**  Abstraction is breaking code into pieces so they are understandable. it is useful to make complex algs easier to understand

# %% [markdown]
# # Getting Started with Sequential Data in Python

# %% [markdown]
# ## Three data types
#
# * List
# * String
# * Tuple

# %%
L = [1,2,3]
type(L)
# Out:
# list

# %%
s = "Bob"
type(s)
# Out:
# str

# %%
tup = (1,2,3)
type(tup)
# Out:
# tuple

# %% [markdown]
# ### Basic Sequence Operations
#
# |Operation  | Purpose     |
# |---------- | ------------|
# | +         | concatenate |
# | *         | replicate   |
# | s[i]      | index       |
# | s[i:j]    | slice       |
# | len(s)    | length      |
# | s in t    | membership  |
# | s not in t| membership  |

# %% [markdown]
# ## More about indexing
#
# <img src="https://github.com/yardsale8/STAT489/blob/master/img/string_index.png?raw=true" width="500">

# %%
s = "Hello Bob"
s[3]
# Out:
# 'l'

# %%
s[-2]
# Out:
# 'o'

# %% [markdown]
# <img src="https://github.com/yardsale8/STAT489/blob/master/img/list_index.png?raw=true" width = "400">

# %%
L = ['A', 'B', 'C', 'D', 'F']
L[0]
# Out:
# 'A'

# %%
L[-4]
# Out:
# 'B'

# %% [markdown]
# ## Indexing `numpy` arrays
#
# * `numpy` are numerically efficient sequence arrays
# * multiple dimensions
# * can index more than one dimension with commas

# %%
from skimage import data
import matplotlib.pylab as plt
% matplotlib inline

# %%
cat = data.chelsea()
plt.imshow(cat)

# %% [markdown]
# An image is 3 dimensional

# %%
cat.shape
# Out:
# (300, 451, 3)

# %% [markdown]
# ### RGB as a different type of `int`
#
# * Python `int` is infinite precision
# * uint8 is 8 bit
#     * only 0 through 255 possible

# %%
cat.dtype
# Out:
# dtype('uint8')

# %%
# Watch out for overflow
cat[1,0] + cat[1,1]
# Out:
# array([ 35, 245, 213], dtype=uint8)

# %%
cat[1,:2]
# Out:
# array([[146, 123, 107],
#        [145, 122, 106]], dtype=uint8)

# %%
(146 + 145) % 256
# Out:
# 35

# %% [markdown]
# ## Indexing 1, 2, or 3 dimensions

# %%
cat[1]
# Out:
# array([[146, 123, 107],
#        [145, 122, 106],
#        [143, 120, 104],
#        ...,
#        [ 46,  29,  13],
#        [ 45,  29,  13],
#        [ 47,  30,  14]], dtype=uint8)

# %%
cat[1,2]
# Out:
# array([143, 120, 104], dtype=uint8)

# %%
cat[1,2,0]
# Out:
# 143

# %% [markdown]
# ## Slicing
# <img src="https://github.com/yardsale8/STAT489/blob/master/img/string_index.png?raw=true" width="500">

# %%
s[1:7]
# Out:
# 'ello B'

# %%
s[:4]
# Out:
# 'Hell'

# %%
s[2:]
# Out:
# 'llo Bob'

# %%
s[:]
# Out:
# 'Hello Bob'

# %%
s[1::2]
# Out:
# 'el o'

# %% [markdown]
# ## Slicing works for all sequences

# %%
L[1:7]
# Out:
# ['B', 'C', 'D', 'F']

# %%
tup[1:]
# Out:
# (2, 3)

# %% [markdown]
# ## Slicing `numpy` arrays
#
# You can slice an any/all dimensions

# %%
cat[:3,:3]
# Out:
# array([[[143, 120, 104],
#         [143, 120, 104],
#         [141, 118, 102]],
#
#        [[146, 123, 107],
#         [145, 122, 106],
#         [143, 120, 104]],
#
#        [[148, 126, 112],
#         [147, 125, 111],
#         [146, 122, 109]]], dtype=uint8)

# %%
plt.imshow(cat[100:200,50:250])

# %% [markdown]
# ## Arithmetic

# %%
"123" + "abc"
# Out:
# '123abc'

# %%
3*[1,2,3]
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
2*('a', 'b') + ('c',)
# Out:
# ('a', 'b', 'a', 'b', 'c')

# %% [markdown]
# ## Boolean expressions

# %%
1 in [1,2,3]
# Out:
# True

# %%
5 in [1,2,3]
# Out:
# False

# %%
"a" not in "Todd"
# Out:
# True

# %%
"a" in ["a", "b", "c"]
# Out:
# True

# %%
"a" in ["abc", "def"]
# Out:
# False

# %%
"todd" == "Todd"
# Out:
# False
